# %%
"""
creating the Silver layer database:
Create the Notebook: Create a new notebook named Silverlayer_DB.
Write Spark SQL Command: Use the command CREATE DATABASE IF NOT EXISTS globalretail_silver to create the Silver layer database.
"""

# %%
spark.sql("create database if not exists globalretail_silver")

# %%
# %sql
show databases
