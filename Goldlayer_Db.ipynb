# %% [markdown]
# This notebook performs the following tasks to create the Gold layer database:
#
# 1. **Create Gold Layer Database**: Creates the Gold layer database named `globalretail_gold` if it does not already exist.
# 2. **Set Current Database**: Sets the current database to `globalretail_gold` to ensure subsequent operations are performed within this database.

# %%
spark.sql("CREATE DATABASE IF NOT EXISTS globalretail_gold")
spark.sql("USE globalretail_gold")

# %%
# %sql 
select current_database()
