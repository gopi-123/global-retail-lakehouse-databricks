# %% [markdown]
# # Bronze Layer DB Creation
#
# ## Notebook Description
#
# This notebook sets up the initial environment for a Databricks data engineering workflow.
#
# **It performs the following steps:**
# - Creates a database named `globalretail_bronze` if it does not already exist.
# - Lists all available databases in the workspace.
# - Sets the current working database to `globalretail_bronze`.
#
# These steps are typically the foundation for ingesting and processing raw data in a medallion architecture, where the **bronze** layer is used for raw, unprocessed data.

# %%
# Create the 'globalretail_bronze' database if it does not exist
spark.sql("create database if not exists globalretail_bronze")

# %%
spark.sql("show databases").show()

# %%
spark.sql("use globalretail_bronze")

# %%
# %sql
select current_database()
